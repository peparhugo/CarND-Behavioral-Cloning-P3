# %%
#import libraries
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
import os
from keras.models import Sequential
from keras.layers.core import Dense, Activation, Flatten, Dropout
from keras.layers.convolutional import Convolution2D
from keras.layers.pooling import MaxPooling2D
import pandas as pd
import datetime
import matplotlib.image as mpimg
# Out:
# Using TensorFlow backend.

# %%
#load data and name columns
data_csv = pd.read_csv("data/driving_log.csv",sep=",")
data_csv.columns=["center_image","right_image","left_image","steering_angle","throttle","break","speed"]

# %%
#create next frame time difference and session count based on time diff
#the session count can be used to associate training sessions and remove poor training sessions if need be
time_diff_list=[0]
training_session=[1]
k=1
for i in range(len(data_csv)-1):
    time_diff=(datetime.datetime.strptime(data_csv["center_image"].iloc[i+1][89:112],"%Y_%m_%d_%H_%M_%S_%f")-
         datetime.datetime.strptime(data_csv["center_image"].iloc[i][89:112],"%Y_%m_%d_%H_%M_%S_%f")).total_seconds()
    
    if  time_diff>0.5:
        k+=1
    time_diff_list.append(time_diff)
    training_session.append(k)

# %%
#add new columns to dataframe
data_csv["train_session"]=training_session
data_csv["time_diff"]=time_diff_list
data_csv=data_csv.loc[data_csv["train_session"]>=23]

# %%
#view the dataset
data_csv
# Out:
#                                             center_image  \
# 6478   /home/pepar/Python-Projects/Self_driving_car/C...
# 6479   /home/pepar/Python-Projects/Self_driving_car/C...
# 6480   /home/pepar/Python-Projects/Self_driving_car/C...
# 6481   /home/pepar/Python-Projects/Self_driving_car/C...
# 6482   /home/pepar/Python-Projects/Self_driving_car/C...
# 6483   /home/pepar/Python-Projects/Self_driving_car/C...
# 6484   /home/pepar/Python-Projects/Self_driving_car/C...
# 6485   /home/pepar/Python-Projects/Self_driving_car/C...
# 6486   /home/pepar/Python-Projects/Self_driving_car/C...
# 6487   /home/pepar/Python-Projects/Self_driving_car/C...
# 6488   /home/pepar/Python-Projects/Self_driving_car/C...
# 6489   /home/pepar/Python-Projects/Self_driving_car/C...
# 6490   /home/pepar/Python-Projects/Self_driving_car/C...
# 6491   /home/pepar/Python-Projects/Self_driving_car/C...
# 6492   /home/pepar/Python-Projects/Self_driving_car/C...
# 6493   /home/pepar/Python-Projects/Self_driving_car/C...
# 6494   /home/pepar/Python-Projects/Self_driving_car/C...
# 6495   /home/pepar/Python-Projects/Self_driving_car/C...
# 6496   /home/pepar/Python-Projects/Self_driving_car/C...
# 6497   /home/pepar/Python-Projects/Self_driving_car/C...
# 6498   /home/pepar/Python-Projects/Self_driving_car/C...
# 6499   /home/pepar/Python-Projects/Self_driving_car/C...
# 6500   /home/pepar/Python-Projects/Self_driving_car/C...
# 6501   /home/pepar/Python-Projects/Self_driving_car/C...
# 6502   /home/pepar/Python-Projects/Self_driving_car/C...
# 6503   /home/pepar/Python-Projects/Self_driving_car/C...
# 6504   /home/pepar/Python-Projects/Self_driving_car/C...
# 6505   /home/pepar/Python-Projects/Self_driving_car/C...
# 6506   /home/pepar/Python-Projects/Self_driving_car/C...
# 6507   /home/pepar/Python-Projects/Self_driving_car/C...
# ...                                                  ...
# 40952  /home/pepar/Python-Projects/Self_driving_car/C...
# 40953  /home/pepar/Python-Projects/Self_driving_car/C...
# 40954  /home/pepar/Python-Projects/Self_driving_car/C...
# 40955  /home/pepar/Python-Projects/Self_driving_car/C...
# 40956  /home/pepar/Python-Projects/Self_driving_car/C...
# 40957  /home/pepar/Python-Projects/Self_driving_car/C...
# 40958  /home/pepar/Python-Projects/Self_driving_car/C...
# 40959  /home/pepar/Python-Projects/Self_driving_car/C...
# 40960  /home/pepar/Python-Projects/Self_driving_car/C...
# 40961  /home/pepar/Python-Projects/Self_driving_car/C...
# 40962  /home/pepar/Python-Projects/Self_driving_car/C...
# 40963  /home/pepar/Python-Projects/Self_driving_car/C...
# 40964  /home/pepar/Python-Projects/Self_driving_car/C...
# 40965  /home/pepar/Python-Projects/Self_driving_car/C...
# 40966  /home/pepar/Python-Projects/Self_driving_car/C...
# 40967  /home/pepar/Python-Projects/Self_driving_car/C...
# 40968  /home/pepar/Python-Projects/Self_driving_car/C...
# 40969  /home/pepar/Python-Projects/Self_driving_car/C...
# 40970  /home/pepar/Python-Projects/Self_driving_car/C...
# 40971  /home/pepar/Python-Projects/Self_driving_car/C...
# 40972  /home/pepar/Python-Projects/Self_driving_car/C...
# 40973  /home/pepar/Python-Projects/Self_driving_car/C...
# 40974  /home/pepar/Python-Projects/Self_driving_car/C...
# 40975  /home/pepar/Python-Projects/Self_driving_car/C...
# 40976  /home/pepar/Python-Projects/Self_driving_car/C...
# 40977  /home/pepar/Python-Projects/Self_driving_car/C...
# 40978  /home/pepar/Python-Projects/Self_driving_car/C...
# 40979  /home/pepar/Python-Projects/Self_driving_car/C...
# 40980  /home/pepar/Python-Projects/Self_driving_car/C...
# 40981  /home/pepar/Python-Projects/Self_driving_car/C...
#
#                                              right_image  \
# 6478    /home/pepar/Python-Projects/Self_driving_car/...
# 6479    /home/pepar/Python-Projects/Self_driving_car/...
# 6480    /home/pepar/Python-Projects/Self_driving_car/...
# 6481    /home/pepar/Python-Projects/Self_driving_car/...
# 6482    /home/pepar/Python-Projects/Self_driving_car/...
# 6483    /home/pepar/Python-Projects/Self_driving_car/...
# 6484    /home/pepar/Python-Projects/Self_driving_car/...
# 6485    /home/pepar/Python-Projects/Self_driving_car/...
# 6486    /home/pepar/Python-Projects/Self_driving_car/...
# 6487    /home/pepar/Python-Projects/Self_driving_car/...
# 6488    /home/pepar/Python-Projects/Self_driving_car/...
# 6489    /home/pepar/Python-Projects/Self_driving_car/...
# 6490    /home/pepar/Python-Projects/Self_driving_car/...
# 6491    /home/pepar/Python-Projects/Self_driving_car/...
# 6492    /home/pepar/Python-Projects/Self_driving_car/...
# 6493    /home/pepar/Python-Projects/Self_driving_car/...
# 6494    /home/pepar/Python-Projects/Self_driving_car/...
# 6495    /home/pepar/Python-Projects/Self_driving_car/...
# 6496    /home/pepar/Python-Projects/Self_driving_car/...
# 6497    /home/pepar/Python-Projects/Self_driving_car/...
# 6498    /home/pepar/Python-Projects/Self_driving_car/...
# 6499    /home/pepar/Python-Projects/Self_driving_car/...
# 6500    /home/pepar/Python-Projects/Self_driving_car/...
# 6501    /home/pepar/Python-Projects/Self_driving_car/...
# 6502    /home/pepar/Python-Projects/Self_driving_car/...
# 6503    /home/pepar/Python-Projects/Self_driving_car/...
# 6504    /home/pepar/Python-Projects/Self_driving_car/...
# 6505    /home/pepar/Python-Projects/Self_driving_car/...
# 6506    /home/pepar/Python-Projects/Self_driving_car/...
# 6507    /home/pepar/Python-Projects/Self_driving_car/...
# ...                                                  ...
# 40952   /home/pepar/Python-Projects/Self_driving_car/...
# 40953   /home/pepar/Python-Projects/Self_driving_car/...
# 40954   /home/pepar/Python-Projects/Self_driving_car/...
# 40955   /home/pepar/Python-Projects/Self_driving_car/...
# 40956   /home/pepar/Python-Projects/Self_driving_car/...
# 40957   /home/pepar/Python-Projects/Self_driving_car/...
# 40958   /home/pepar/Python-Projects/Self_driving_car/...
# 40959   /home/pepar/Python-Projects/Self_driving_car/...
# 40960   /home/pepar/Python-Projects/Self_driving_car/...
# 40961   /home/pepar/Python-Projects/Self_driving_car/...
# 40962   /home/pepar/Python-Projects/Self_driving_car/...
# 40963   /home/pepar/Python-Projects/Self_driving_car/...
# 40964   /home/pepar/Python-Projects/Self_driving_car/...
# 40965   /home/pepar/Python-Projects/Self_driving_car/...
# 40966   /home/pepar/Python-Projects/Self_driving_car/...
# 40967   /home/pepar/Python-Projects/Self_driving_car/...
# 40968   /home/pepar/Python-Projects/Self_driving_car/...
# 40969   /home/pepar/Python-Projects/Self_driving_car/...
# 40970   /home/pepar/Python-Projects/Self_driving_car/...
# 40971   /home/pepar/Python-Projects/Self_driving_car/...
# 40972   /home/pepar/Python-Projects/Self_driving_car/...
# 40973   /home/pepar/Python-Projects/Self_driving_car/...
# 40974   /home/pepar/Python-Projects/Self_driving_car/...
# 40975   /home/pepar/Python-Projects/Self_driving_car/...
# 40976   /home/pepar/Python-Projects/Self_driving_car/...
# 40977   /home/pepar/Python-Projects/Self_driving_car/...
# 40978   /home/pepar/Python-Projects/Self_driving_car/...
# 40979   /home/pepar/Python-Projects/Self_driving_car/...
# 40980   /home/pepar/Python-Projects/Self_driving_car/...
# 40981   /home/pepar/Python-Projects/Self_driving_car/...
#
#                                               left_image  steering_angle  \
# 6478    /home/pepar/Python-Projects/Self_driving_car/...        0.000000
# 6479    /home/pepar/Python-Projects/Self_driving_car/...        0.000000
# 6480    /home/pepar/Python-Projects/Self_driving_car/...        0.000000
# 6481    /home/pepar/Python-Projects/Self_driving_car/...        0.000000
# 6482    /home/pepar/Python-Projects/Self_driving_car/...        0.000000
# 6483    /home/pepar/Python-Projects/Self_driving_car/...        0.000000
# 6484    /home/pepar/Python-Projects/Self_driving_car/...        0.000000
# 6485    /home/pepar/Python-Projects/Self_driving_car/...       -0.113858
# 6486    /home/pepar/Python-Projects/Self_driving_car/...       -0.084473
# 6487    /home/pepar/Python-Projects/Self_driving_car/...       -0.071879
# 6488    /home/pepar/Python-Projects/Self_driving_car/...       -0.071879
# 6489    /home/pepar/Python-Projects/Self_driving_car/...        0.000000
# 6490    /home/pepar/Python-Projects/Self_driving_car/...        0.000000
# 6491    /home/pepar/Python-Projects/Self_driving_car/...        0.000000
# 6492    /home/pepar/Python-Projects/Self_driving_car/...        0.021504
# 6493    /home/pepar/Python-Projects/Self_driving_car/...        0.021504
# 6494    /home/pepar/Python-Projects/Self_driving_car/...        0.021504
# 6495    /home/pepar/Python-Projects/Self_driving_car/...        0.021504
# 6496    /home/pepar/Python-Projects/Self_driving_car/...        0.021504
# 6497    /home/pepar/Python-Projects/Self_driving_car/...        0.008910
# 6498    /home/pepar/Python-Projects/Self_driving_car/...        0.000000
# 6499    /home/pepar/Python-Projects/Self_driving_car/...        0.000000
# 6500    /home/pepar/Python-Projects/Self_driving_car/...        0.000000
# 6501    /home/pepar/Python-Projects/Self_driving_car/...        0.000000
# 6502    /home/pepar/Python-Projects/Self_driving_car/...        0.000000
# 6503    /home/pepar/Python-Projects/Self_driving_car/...        0.000000
# 6504    /home/pepar/Python-Projects/Self_driving_car/...        0.000000
# 6505    /home/pepar/Python-Projects/Self_driving_car/...       -0.155837
# 6506    /home/pepar/Python-Projects/Self_driving_car/...       -0.155837
# 6507    /home/pepar/Python-Projects/Self_driving_car/...        0.000000
# ...                                                  ...             ...
# 40952   /home/pepar/Python-Projects/Self_driving_car/...       -0.254094
# 40953   /home/pepar/Python-Projects/Self_driving_car/...       -0.229035
# 40954   /home/pepar/Python-Projects/Self_driving_car/...       -0.074500
# 40955   /home/pepar/Python-Projects/Self_driving_car/...       -0.061971
# 40956   /home/pepar/Python-Projects/Self_driving_car/...        0.000000
# 40957   /home/pepar/Python-Projects/Self_driving_car/...        0.000000
# 40958   /home/pepar/Python-Projects/Self_driving_car/...       -0.045264
# 40959   /home/pepar/Python-Projects/Self_driving_car/...       -0.095383
# 40960   /home/pepar/Python-Projects/Self_driving_car/...       -0.145503
# 40961   /home/pepar/Python-Projects/Self_driving_car/...       -0.158032
# 40962   /home/pepar/Python-Projects/Self_driving_car/...       -0.170562
# 40963   /home/pepar/Python-Projects/Self_driving_car/...       -0.183092
# 40964   /home/pepar/Python-Projects/Self_driving_car/...       -0.183092
# 40965   /home/pepar/Python-Projects/Self_driving_car/...       -0.183092
# 40966   /home/pepar/Python-Projects/Self_driving_car/...        0.000000
# 40967   /home/pepar/Python-Projects/Self_driving_car/...        0.000000
# 40968   /home/pepar/Python-Projects/Self_driving_car/...        0.000000
# 40969   /home/pepar/Python-Projects/Self_driving_car/...       -0.329273
# 40970   /home/pepar/Python-Projects/Self_driving_car/...       -0.696814
# 40971   /home/pepar/Python-Projects/Self_driving_car/...        0.000000
# 40972   /home/pepar/Python-Projects/Self_driving_car/...        0.000000
# 40973   /home/pepar/Python-Projects/Self_driving_car/...        0.000000
# 40974   /home/pepar/Python-Projects/Self_driving_car/...        0.000000
# 40975   /home/pepar/Python-Projects/Self_driving_car/...        0.000000
# 40976   /home/pepar/Python-Projects/Self_driving_car/...        0.000000
# 40977   /home/pepar/Python-Projects/Self_driving_car/...        0.000000
# 40978   /home/pepar/Python-Projects/Self_driving_car/...        0.000000
# 40979   /home/pepar/Python-Projects/Self_driving_car/...        0.000000
# 40980   /home/pepar/Python-Projects/Self_driving_car/...        0.000000
# 40981   /home/pepar/Python-Projects/Self_driving_car/...        0.000000
#
#        throttle  break     speed  train_session  time_diff
# 6478   0.841635    0.0  30.15021             23      1.562
# 6479   0.841635    0.0  30.15021             23      0.105
# 6480   0.841635    0.0  30.15021             23      0.115
# 6481   0.841635    0.0  30.15023             23      0.115
# 6482   0.841635    0.0  30.15021             23      0.116
# 6483   0.841635    0.0  30.15020             23      0.101
# 6484   0.841635    0.0  30.15021             23      0.101
# 6485   0.841635    0.0  30.14808             23      0.116
# 6486   0.841635    0.0  30.14986             23      0.100
# 6487   0.841635    0.0  30.15040             23      0.102
# 6488   0.841635    0.0  30.15011             23      0.115
# 6489   0.841635    0.0  30.15019             23      0.100
# 6490   0.841635    0.0  30.15018             23      0.115
# 6491   0.841635    0.0  30.15019             23      0.100
# 6492   0.841635    0.0  30.15011             23      0.117
# 6493   0.841635    0.0  30.15014             23      0.101
# 6494   0.841635    0.0  30.15018             23      0.118
# 6495   0.841635    0.0  30.15018             23      0.115
# 6496   0.841635    0.0  30.15020             23      0.101
# 6497   0.841635    0.0  30.15022             23      0.100
# 6498   0.841635    0.0  30.15021             23      0.115
# 6499   0.841635    0.0  30.15018             23      0.117
# 6500   0.841635    0.0  30.15021             23      0.101
# 6501   0.841635    0.0  30.15020             23      0.101
# 6502   0.841635    0.0  30.15022             23      0.100
# 6503   0.841635    0.0  30.15017             23      0.114
# 6504   0.841635    0.0  30.15022             23      0.104
# 6505   0.841635    0.0  30.14460             23      0.114
# 6506   0.841635    0.0  30.14761             23      0.101
# 6507   0.841635    0.0  30.14947             23      0.114
# ...         ...    ...       ...            ...        ...
# 40952  0.787051    0.0  30.13533            499      0.111
# 40953  0.787051    0.0  30.13628            499      0.101
# 40954  0.798309    0.0  30.14070            499      0.115
# 40955  0.798309    0.0  30.14022            499      0.106
# 40956  0.798309    0.0  30.13924            499      0.111
# 40957  0.798309    0.0  30.13925            499      0.109
# 40958  0.798309    0.0  30.13879            499      0.115
# 40959  0.798309    0.0  30.13771            499      0.111
# 40960  0.798309    0.0  30.13643            499      0.104
# 40961  0.798309    0.0  30.13722            499      0.111
# 40962  0.791362    0.0  30.13576            499      0.100
# 40963  0.778430    0.0  30.13265            499      0.103
# 40964  0.778430    0.0  30.13305            499      0.116
# 40965  0.778430    0.0  30.13331            499      0.102
# 40966  0.752566    0.0  30.13353            499      0.112
# 40967  0.000000    0.0  29.88691            499      0.100
# 40968  0.000000    0.0  29.58737            499      0.101
# 40969  0.028380    0.0  29.19674            499      0.115
# 40970  0.153389    0.0  28.65348            499      0.101
# 40971  0.000000    0.0  28.29328            499      0.118
# 40972  0.000000    0.0  28.00284            499      0.100
# 40973  0.000000    0.0  27.72089            499      0.115
# 40974  0.000000    0.0  27.38712            499      0.116
# 40975  0.000000    0.0  27.11213            499      0.100
# 40976  0.000000    0.0  26.78576            499      0.116
# 40977  0.000000    0.0  26.51681            499      0.102
# 40978  0.000000    0.0  26.25056            499      0.100
# 40979  0.000000    0.0  25.93459            499      0.116
# 40980  0.000000    0.0  25.62242            499      0.115
# 40981  0.000000    0.0  25.36516            499      0.103
#
# [34504 rows x 9 columns]

# %%
# basic plot
print(min(data_csv["steering_angle"]))
print(max(data_csv["steering_angle"]))
plt.figure(figsize=(20,10))
plt.boxplot(data_csv["steering_angle"])

# %%
#view steering anlges by training session
for unique_session in np.unique(data_csv["train_session"])[10:20]:
    plt.figure(figsize=(20,10))
    plt.plot(data_csv.loc[data_csv["train_session"]==unique_session]["steering_angle"])
    plt.show()

# %%
#create scaling image function
def scaling(img,scale_x,scale_y):
    """
    Input an image in a numpy array, scale of the x and ydirection as a decimal
    Outputs a numpy array as the scaled image
    """
    return cv2.resize(img,None,fx=scale_x, fy=scale_y, interpolation = cv2.INTER_LINEAR)

# %%
#create normalizing function to normailize augmented data set
def min_max_normalization(x,min,max):
    """
    This function takes an n by m array and normalizes each value based on the average of min and max values
    of the RBG scale (min=0 and max=255).
    
    It return an n by m array
    """
    avg_value=(max+min)/2.0
    norm_array = np.zeros(x.shape)+avg_value
    normalized_x= (x-norm_array)/norm_array
    return normalized_x

# %%
#split training set into training and validation set
from sklearn.cross_validation import train_test_split

y_train, y_validation = train_test_split(data_csv, test_size=0.2, random_state=88)

# %%
#used generator code from Behavioral cloning lesson
from sklearn.utils import shuffle
def generator(samples, batch_size=32):
    num_samples = len(samples)
    while 1: # Loop forever so the generator never terminates
        shuffle(samples)
        for offset in range(0, num_samples, batch_size):
            batch_samples = samples[offset:offset+batch_size]

            images = []
            angles = []
            for index, batch_sample in batch_samples.iterrows():
                name = batch_sample[0]
                center_image = min_max_normalization(scaling(mpimg.imread(name),0.5,0.5),0,255)
                center_angle = float(batch_sample[3])
                images.append(center_image)
                angles.append(center_angle)
                images.append(np.fliplr(center_image))
                angles.append(-center_angle)

            X_train = np.array(images)
            y_train = np.array(angles)
            yield shuffle(X_train, y_train)

# compile and train the model using the generator function
train_generator = generator(y_train, batch_size=32)
validation_generator = generator(y_validation, batch_size=32)

# %%
model = Sequential()
# TODO: Re-construct the network and add a convolutional layer before the flatten layer.
# Create the Sequential model
#convolutuonal layer with 10 layers and 3 by 3, 2x2 max pooling and activation
model.add(Convolution2D(10, 3, 3, border_mode='valid', input_shape=(80, 160, 3)))
model.add(MaxPooling2D((2,2)))
model.add(Activation('relu'))

#convolutuonal layer with 20 layers and 3 by 3, 2x2 max pooling and activation
model.add(Convolution2D(20, 3, 3, border_mode='valid'))
model.add(MaxPooling2D((2,2)))
model.add(Activation('relu'))

#convolutuonal layer with 20 layers and 3 by 3, 2x2 max pooling and activation
model.add(Convolution2D(30, 3, 3, border_mode='valid'))
model.add(MaxPooling2D((2,2)))
model.add(Activation('relu'))

#a flatten layer
model.add(Flatten())

#1st layer dense to 800, activation and 50% dropout
model.add(Dense(800))
model.add(Activation('relu'))
model.add(Dropout(0.5))

#2nd layer dense to 500, activation and 50% dropout
model.add(Dense(500))
model.add(Activation('relu'))
model.add(Dropout(0.5))

#3rd layer dense to 200, activation and 50% dropout
model.add(Dense(200))
model.add(Activation('relu'))
model.add(Dropout(0.5))

#4th layer dense to 100, activation and 50% dropout
model.add(Dense(100))
model.add(Activation('relu'))
model.add(Dropout(0.5))

#5th layer dense to 64, activation and 50% dropout
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))

#6th layer dense to 32 and activation
model.add(Dense(32))
model.add(Activation('relu'))

#7th layer dense to 16 and activation
model.add(Dense(16))
model.add(Activation('relu'))

#8th layer dense to 1 for regression output
model.add(Dense(1))

# %%
#use adam optimizer and mean squared error as loss function and output mean absolute error as secondary measure
model.compile('adam', 'mean_squared_error', ['mae'])
#this line of code is taken from the behavioral learning lesson
model.fit_generator(train_generator, samples_per_epoch= len(y_train)*2, validation_data=validation_generator, nb_val_samples=len(y_validation)*2, nb_epoch=9)
# Out:
# Epoch 1/1
# 55206/55206 [==============================] - 707s - loss: 0.0210 - mean_absolute_error: 0.0818 - val_loss: 0.0221 - val_mean_absolute_error: 0.0848

# %%
#save model
model.save("model.h5")

# %%
#delete model for restart
del model
